# %% [markdown]
# ### <a name="index"></a>Index
#
# [Introducción IAM: usuarios, grupos y políticas](#mark_01)
#
# [Práctica IAM Usuarios y Grupos](#mark_02)
#
# [Políticas IAM](#mark_03)
#
# [Visión general IAM MFA "Multi Facto Authentication"](#mark_04)
#
# [Configuración IAM MFA](#mark_05)
#
# [AWS Access Keys, CLI y SDK](#mark_06)
#
# [Setup AWS CLI en Mac](#mark_07)
#
# [Setup AWS CLI en Windows](#mark_08)
#
# [Setup AWS CLI en Linux](#mark_09)
#
# [Configuración AWS CLI con Access Keys](#mark_10)
#
# [AWS CloudShell](#mark_11)
#
# [Roles IAM para AWS](#mark_12)
#
# [Práctica de roles en IAM](#mark_13)
#
# [Herramientas de seguridad en IAM](#mark_14)
#
# [Práctica de las herramientas de seguridad](#mark_15)
#
# [Mejores Practicas dentro de IAM](#mark_16)
#
# [Modelo de responsabilidad compartida en IAM](#mark_17)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)
#
# [](#mark_)

# %% [markdown]
# ### <a name='mark_01'></a> Introducción IAM: usuarios, grupos y políticas
#
# ### [Indice](#index)
#
# IAM es un servicio para la gestión de acceso de identidad. Los conceptos básicos:
#
# _ Root account: Es la cuenta que se crea de manea predeterminada.
#
# _ Usuarios: Son personas que tienen acceso a servicios de la organización, se pueden agrupar y no tienen que pertenecer solo a un grupo.
#
# _ Grupos: Solo contienen usuarios y no otros grupos.
#
# _ Políticas: A los usuarios o grupos se les puede asignar políticas como documentos JSON. Estas políticas definen los permisos de los usuarios o grupos para cualquiera de los servicios dentro de AWS y para definirlas se aplica el principio de privilegios mínimos, es decir, no otorgar más privilegios de los que un usuario necesita.
#
# ![](img_01.png)

# %% [markdown]
# ### <a name='mark_02'></a> Práctica IAM Usuarios y Grupos
#
# ### [Indice](#index)
#
# ## Que es AWS IAM:
#
# Identity and Access Managment, Servicio web para controlar de manera segura el acceso a servicios de AWS, puede administrar de forma centralizada a los usuarios, las credenciales de seguridad y los permisos que controlan a qué recursos y aplicaciones de AWS pueden obtener acceso
#
# ## Usuarios:
#
# Es una entidad que se crea en AWS para representar a la persona o a la aplicación que se utiliza para interactuar con AWS.
#
# ## Permiso:
#
# Es la acción que se le otorga a una Persona, Rol o Grupo para que pueda realizar cierta acción específica sobre un recurso en AWS.
#
# ## Rol:
#
# Una identidad de IAM que se puede crear en una cuenta y que tiene permisos específicos. Un rol de IAM tiene algunas similitudes con un usuario de IAM. Los roles y los usuarios son identidades de AWS con políticas de permisos que determinan lo que la identidad puede y no puede hacer en AWS.
#
# ## Grupos:
#
# Es la forma simple de administrar a un conjunto de usuarios. Los grupos permiten especificar permisos para varios usuarios, lo que puede facilitar la administración de permisos.
#
# ## Políticas:
#
# Es un objeto de AWS que, cuando se asocia a una identidad o un recurso, define sus permisos. AWS evalúa estas políticas cuando una entidad principal de IAM (usuario o rol) realiza una solicitud. Los permisos en las políticas determinan si la solicitud se permite o se deniega.
#
# ## ACL:
#
# Access Control List, se utiliza para controlar qué entidades principales de otras cuentas pueden tener acceso al recurso al que la ACL está asociada. Las ACL son similares a las políticas basadas en recursos, aunque son el único tipo de política que no utiliza la estructura de los documentos de política JSON. Las ACL son políticas de permisos para varias cuentas que conceden permisos a la entidad principal especificada. Las ACL no pueden conceder permisos a entidades dentro de una misma cuenta.
#
# ![](img_03.png)
#
# ![](img_04.png)
#
# ![](img_05.png)
#
# ![](img_06.png)
#
# ![](img_07.png)
#
# ![](img_08.png)
#
# ![](img_09.png)
#
# ![](img_10.png)

# %% [markdown]
# ### <a name='mark_03'></a> Políticas IAM
#
# ### [Indice](#index)
#
# Son documentos en JSON que van a poder ser utilizados junto con los usuarios y los grupos.
#
# ## Herencia de Politicas de IAM
#
# Los accesos de un grupo se heredan a los usuarios miembros del grupo.
#
# Se pueden crear politicas (inline politicy) para usuarios que no pertenecen a un grupo. (Es mejor practica crear un grupo y darle los permisos al grupo, no a usuarios). Un usuario puede compartir dos politicas, asi obtiene mas permisos.
#
# ![](img_11.png)
#
# ## Estructura de las politicas
#
# ```json
# {
# 	"Version": "2012-10-17",
# 	"Id": "S3-Account-Permissions",
# 	"Statement": [
# 		{
# 			"Sid": "1",
# 			"Effect": "Allow",
# 			"Principal": {
# 				"AWS": "arn:aws:iam::123456789012:root"
# 			},
# 			"Action": [
# 				"s3:GetObject",
# 				"s3:PutObject"
# 			],
# 			"Rosource": [
# 				"arn:aws:s3:::my-bucket/*"
# 			]
# 		}
# 	]
# }
# ```
# _ Consiste en:
#
#     _ Version
#
#     _ Id: Un identificador para la politica
#
#     _ Declaracion: una o mas
#
# _ Declaracion consiste de:
#
#     _ Sid: un identificador
#
#     _ Efecto: permite o deniega el acceso
#
#     _ Principal: cuenta/usuario/rol al que se aplica esta politica
#
#     _ Accion: lista de acciones
#
#     _ Recursos: lista de recursos
#
#     _ Condicion: condiciones (opcional)
#
#
# https://policysim.aws.amazon.com/home/index.jsp?#
#
# https://awspolicygen.s3.amazonaws.com/policygen.html

# %% [markdown]
# ### <a name='mark_04'></a> Visión general IAM MFA Multi Facto Authentication
#
# ### [Indice](#index)
#
# ![](img_12.png)
#
# ![](img_13.png)
#
# ![](img_14.png)
#
# ![](img_15.png)

# %% [markdown]
# ### <a name='mark_05'></a> Configuración IAM MFA
#
# ### [Indice](#index)
#
# ![](img_16.png)
# ![](img_17.png)
# ![](img_18.png)
# En la siguiente imagen, veremos a la izquierda "laptop Screen" y a la derecha "Cellphone Screen", en la pantalla de la izquierda solicitamos el código QR, el cual debe ser scanneado con una aplicación de celular, en este ejemplo se utiliza "Authy" la cual genera 2 codigos que deben ser ingresados en la laptop.
# ![](img_19.png)
# MFA correctamente configurado.
# ![](img_20.png)

# %% [markdown]
# ### <a name='mark_06'></a> AWS Access Keys, CLI y SDK
#
# ### [Indice](#index)
#
# AWS CLI es un programa para nuestra computadora que nos permite interactuar con todos los servicios de AWS
#
# El Access Key y Secret Key son llaves para hacer la conexión de CLI y SDK
#
# La CLI es la herramienta que nos permite interactuar con los servicios de AWS por medio de comandos
#
# El código de desarrollo de la CLI es publico y esta desarrollado en Python
#
# CLI = Command Line Interface
#
# SDK = Software Development Kits
#
# ![](img_21.png)
#
# ![](img_22.png)
#
# La Consola de administración de AWS es una aplicación web que comprende y hace referencia a una amplia colección de consolas de servicio para administrar los recursos de AWS.
#
# ## AWS Access Keys
#
# Las claves de acceso son las credenciales a largo plazo para un usuario de IAM o usuario raíz Cuenta de AWS. Puede utilizar las claves de acceso para firmar solicitudes mediante programación a la AWS CLI o a la API de AWS (directamente o mediante el SDK de AWS). Para obtener más información, consulte Firma de la solicitud de la API de AWS en la Referencia general de Amazon Web Services
#
# _ Access Key ID
#
# _ Secret Key ID
#
# _ NO compartir tus llaves de acceso
#
# ## AWS Command Line Interface (CLI)
#
# ![](img_23.png)
#
# La AWS Command Line Interface (AWS CLI) es una herramienta de código abierto, luego de ser instalado en nuestro local, permite interactuar con los servicios de AWS mediante el uso de comandos en el shell de la línea de comandos, su acceso es mediante las Access Key y los Secret Key.
#
# Herramienta que le permite interactuar con los servicios de AWS mediante los comandos en su shell de linea de comandos
#
# _ Acceso directo a las API publicas de los servicios de AWS
#
# _ Puede desarrollar scripts para administrar sus recursos
#
# _ Es de codigo abierto
#
# ## AWS Software Development Kits (SDK)
#
# _ AWS proporciona un set de librerias para interactuar con sus servicios.
#
# ![](img_24.png)
#
# AWS SDK for JavaScript proporciona una API de JavaScript para los servicios de AWS. Puede usar la API de JavaScript para crear bibliotecas o aplicaciones para Node.js o el navegador.
#
# Podemos usar los lenguajes mas demandados para los servicios de AWS, para las librerías que ofrece AWS.
#
# ![](img_25.png)

# %% [markdown]
# ### <a name='mark_07'></a> Setup AWS CLI en Mac
#
# ### [Indice](#index)
#
# ![](img_26.png)
#
# ![](img_27.png)
#
# ![](img_28.png)
#
# _ Hacemos el download, e instalamos, verificamos la versión `aws --version`.

# %% [markdown]
# ### <a name='mark_08'></a> Setup AWS CLI en Windows
#
# ### [Indice](#index)
#
# ![](img_26.png)
#
# ![](img_27.png)
#
# ![](img_29.png)
#
# _ Hacemos el download, e instalamos, verificamos la versión `aws --version`.

# %% [markdown]
# ### <a name='mark_09'></a> Setup AWS CLI en Linux
#
# ### [Indice](#index)
#
# ![](img_26.png)
#
# ![](img_27.png)
#
# ![](img_30.png)
#
# ![](img_31.png)
#
# ![](img_32.png)
#
# _ Hacemos la verificación la versión `aws --version`.

# %% [markdown]
# ### <a name='mark_10'></a> Configuración AWS CLI con Access Keys
#
# ### [Indice](#index)
#
# _ Con el usuario root, ingresamos a la consola y copiamos el siguiente link.
#
# ![](img_33.png)
#
# _ Luego copiamos ese link en nuestro navegador e ingresamos con el usario NO root que necesitemos.
#
# _ Una vez que ingresamo con el cliente NO root, podemos descargar nuestras Secret Key.
#
# ![](img_34.png)
#
# ![](img_35.png)
#
# ## Recordar que una vez que cerremos esta ventana no podremos recuperar ni el Access Key ID, ni el Secret Access key, por ese motivo lo podemos descargar en como CSV para guardarlo nosotros.
#
# _ Realizamos la configuración mediante el comando `aws configure`
#
# ![](img_36.png)
#
# _ Ya podemos utilizar todos los servicios utilzando la terminal de aws. A continuación vemos el comando `aws iam list-users` que lista en formato json la lista de los usuarios en la cuenta actual.
#
# ![](img_37.png)

# %% [markdown]
# ### <a name='mark_11'></a> AWS CloudShell
#
# ### [Indice](#index)
#
# _ CloudShell es una alternativa online para no usar la aws CLI, recordar que no esta disponible en todas las regiones.
#
# _ Revisamos las regiones.
#
# ![](img_38.png)
#
# ![](img_39.png)
#
# ![](img_40.png)
#
# _ Abriendo CloudShell, con esta funcionalidad no tengo que configurar ni el Access Key ID, ni el Secret Access key, por defecto ya están configurados con todos sus permisos.
#
# ![](img_41.png)
#
# _ Podemos hacer download de distintos archivos de la siguiente forma.
#
# ![](img_42.png)
#
# ![](img_43.png)
#
# _ Cuidado!!! con AWS Delete CloudShell, esta opción NO persiste los cambios creados, a diferecia de Refresh

# %% [markdown]
# ### <a name='mark_12'></a> Roles IAM para AWS
#
# ### [Indice](#index)
#
# Si queremos ejecutar ciertos servicios, por ejemplo ejecutar una VM EC2 y conectara la un S3, debemos crear un rol aplicado a la EC2 para que pueda empezar a interactuar con nuestro S3.
#
# Cuidado!!! también podemos ingresar a EC2 y configurar nuestros Access Key ID, y Secret Access key directamente desde la EC2, pero esto es una mala practica ya que si por algún motivo se hackea nuestra EC2 las claves quedarán comprometidas.
#
# ![](img_44.png)

# %% [markdown]
# ### <a name='mark_13'></a> Práctica de roles en IAM
#
# ### [Indice](#index)
#
# _ Ingresamos a IAM --> Roles --> Create role
#
# ![](img_45.png)
#
# ![](img_46.png)
#
# ![](img_47.png)
#
# _ Me conecto a una EC2 previamente creada por medio de SSH, luego con el comando `aws s3 ls`, listamos los bucket a los que tenemos acceso, como se ve en el ejemplo, no hay acceso.
#
# ![](img_48.png)
#
# _ Si volvemos a las instancias de aws, seleccionamos el servicio EC2 al cual le queremos adjuntar el nuevo rol, Actions --> Security --> Modify IAM role.
#
# ![](img_49.png)
#
# ![](img_50.png)
#
# _ Verificamos el acceso al bucket
#
# ![](img_51.png)

# %% [markdown]
# ### <a name='mark_14'></a> Herramientas de seguridad en IAM
#
# ### [Indice](#index)
#
# ![](img_52.png)
#
# 1. **Credentials Report**: Es un listado o reporte en CSV, que nos va a permitir revisar lo que está pasando con los usuarios; es decir, si tenemos credenciales actualizadas, cuando fue la última vez que las cambiaron, si tenemos el MFA habilitado entre otras cosas. El beneficio de este reporte es que nos permitirá tener un over-view general de cuantos usuarios tenemos en nuestra cuenta de AWS.
#
# 2. **Access Advisor**: Nos va a mostrar a nivel granular todos los permisos por servicios. Esto quiere decir que si los usuarios tienen accesos a todos los servicios de AWS, nos generará un reporte de que servicios están ocupando realmente.
#
# Estos reportes nos ayudan mucho a establecer el principio del mínimo privilegio para implementar políticas más adecuadas y seguras en nuestra cuenta AWS, como también generar auditorias de nuestra cuenta de manera más efectiva.

# %% [markdown]
# ### <a name='mark_15'></a> Práctica de las herramientas de seguridad
#
# ### [Indice](#index)
#
# ## Credential Report
#
# ![](img_53.png)
#
# ![](img_54.png)
#
# Luego de download ya tendremos disponibla la información de los usuarios.
#
# ## Access Advisors.
#
# _ Users --> ingresamos al usuario con doble click, donde podremos ver los servicios utilizados y sus movimientos.
#
# ![](img_55.png)
#
# ![](img_56.png)

# %% [markdown]
# ### <a name='mark_16'></a> Mejores prácticas dentro de IAM
#
# ### [Indice](#index)
#
# * El usuario root no se debe usar, usarlo únicamente para crear usuarios y asignarle permisos para poder operar.
#
# * Se deben crear grupos, donde se metan usuarios.
#
# * Crear políticas seguras para la creación de contraseñas.
#
# * Utilizar el MFA, como 2do factor de autenticación.
#
# * Los roles son poderosos, nos permiten ejecutar acciones a nuestro nombre.
#
# * Utilizar servicios como: Access Key, Secret Key y utilizar y la CLI dentro de AWS.
#
# * Utilizar los reportes que nos ofrece la auditoria de los servicios.
#
# * No compartir usuarios.

# %% [markdown]
# ### <a name='mark_17'></a> Modelo de responsabilidad compartida en IAM
#
# ### [Indice](#index)
#
# El modelo de responsabilidad compartida se refiere a que AWS es reponsable DE la nube (Infraestructura física, la red de AWS, etc) Y nosotros somos responsables de lo que tengamos EN la nube (Usuarios, permisos, políticas, etc)
#
# ![](img_57.png)
